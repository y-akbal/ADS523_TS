# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/ADS523_TS/blob/main/exam/ADS523Finalsecondopart.ipynb)

# %%
import os
import matplotlib.pyplot as plt
import sklearn
import numpy as np
import pandas as pd

# %%
def download_data():  
  import requests
  url = "https://raw.githubusercontent.com/y-akbal/ADS523_TS/main/exam/tsfinal02.csv"
  res = requests.get(url, allow_redirects=True)
  with open('tsfinal02.csv','wb') as file:
    file.write(res.content)

download_data()

# %%
data = pd.read_csv("tsfinal02.csv").iloc[:, -1]

# %%
def sliding_window(data_, lag_size = 50):  
  """
  ## This dude will return sliding window in the form
  X = [x_{t-l},x_{t-l+1},..., x_t], y = [x_{t+1}]
  """
  N = len(data_)
  data = np.array(data_)
  X = []
  y = []
  for i in range(N-lag_size-1):
    X.append(data[i:i+lag_size])
    y.append(data[i+lag_size])
  return np.array(X), np.array(y)
